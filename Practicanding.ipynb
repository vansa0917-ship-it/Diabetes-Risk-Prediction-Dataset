# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url = "diabetes_risk_dataset.csv"
diabetes = pd.read_csv("https://raw.githubusercontent.com/vansa0917-ship-it/Diabetes-Risk-Prediction-Dataset/refs/heads/main/diabetes_risk_dataset.csv")

print(diabetes.head())
# Out:
#    Patient_ID  age  gender   bmi  blood_pressure  fasting_glucose_level  \
# 0           1   77  Female  33.8             154                     93
# 1           2   54    Male  19.2             123                     94
# 2           3   25    Male  33.7             141                    150
# 3           4   23  Female  32.8             140                    145
# 4           5   70    Male  33.7             165                     90
#
#    insulin_level  HbA1c_level  cholesterol_level  triglycerides_level  \
# 0           12.1          5.2                242                  194
# 1            4.6          5.4                212                   76
# 2           10.8          6.9                247                  221
# 3           11.6          6.8                195                  193
# 4           18.3          5.6                217                  170
#
#   physical_activity_level  daily_calorie_intake  sugar_intake_grams_per_day  \
# 0                     Low                  2169                        78.4
# 1                    High                  1881                        16.5
# 2                     Low                  2811                       147.9
# 3                     Low                  2826                        98.3
# 4                Moderate                  2610                        65.8
#
#    sleep_hours  stress_level family_history_diabetes  waist_circumference_cm  \
# 0          8.1             4                      No                   101.1
# 1          6.6             3                      No                    60.0
# 2          6.7            10                     Yes                   114.7
# 3          4.4             9                     Yes                    96.6
# 4          9.1             5                     Yes                   107.4
#
#    diabetes_risk_score diabetes_risk_category
# 0                 52.3            Prediabetes
# 1                  3.7               Low Risk
# 2                 87.3              High Risk
# 3                 76.1              High Risk
# 4                 47.7            Prediabetes

# %%
diabetes.head(10)
# Out:
#    Patient_ID  Año  Genero   IMC  Presión Arterial  Glucosa en ayunas  \
# 0           1   77  Female  33.8               154                 93
# 1           2   54    Male  19.2               123                 94
# 2           3   25    Male  33.7               141                150
# 3           4   23  Female  32.8               140                145
# 4           5   70    Male  33.7               165                 90
# 5           6   57  Female  33.0               145                 88
# 6           7   22  Female  31.9               140                120
# 7           8   39  Female  28.8               123                 88
# 8           9   79  Female  41.7               177                 83
# 9          10   60    Male  35.8               145                146
#
#    Nivel de insulina  Nivel de insulina Glicosilada  Nivel de colesterol  \
# 0               12.1                            5.2                  242
# 1                4.6                            5.4                  212
# 2               10.8                            6.9                  247
# 3               11.6                            6.8                  195
# 4               18.3                            5.6                  217
# 5                4.8                            5.5                  217
# 6               30.5                            6.3                  197
# 7                3.6                            5.3                  204
# 8               22.0                            5.3                  257
# 9               15.6                            7.5                  217
#
#    Nivel de trigliceridos Nivel de actividad fisica  \
# 0                     194                       Low
# 1                      76                      High
# 2                     221                       Low
# 3                     193                       Low
# 4                     170                  Moderate
# 5                     234                       Low
# 6                     178                       Low
# 7                     109                  Moderate
# 8                     144                       Low
# 9                     243                       Low
#
#    Ingesta diaria de caloria  Ingesta de azucar g/dia  Horas de sueño  \
# 0                       2169                     78.4             8.1
# 1                       1881                     16.5             6.6
# 2                       2811                    147.9             6.7
# 3                       2826                     98.3             4.4
# 4                       2610                     65.8             9.1
# 5                       2263                     86.7             5.4
# 6                       2247                    117.0             4.0
# 7                       2218                     24.5             7.9
# 8                       2553                     30.2             7.7
# 9                       2650                    130.8             7.7
#
#    Nivel de estres Historial Familiar  Circunferencia de cintura cm  \
# 0                4                 No                         101.1
# 1                3                 No                          60.0
# 2               10                Yes                         114.7
# 3                9                Yes                          96.6
# 4                5                Yes                         107.4
# 5                5                 No                         105.2
# 6               10                 No                         104.4
# 7                5                 No                          84.8
# 8                5                 No                         124.9
# 9                6                 No                         118.4
#
#    Puntuacion de riesgo Categoria de riesgo
# 0                  52.3         Prediabetes
# 1                   3.7            Low Risk
# 2                  87.3           High Risk
# 3                  76.1           High Risk
# 4                  47.7         Prediabetes
# 5                  40.2         Prediabetes
# 6                  56.9         Prediabetes
# 7                   5.7            Low Risk
# 8                  81.2           High Risk
# 9                  94.3           High Risk

# %%
diabetes.columns = diabetes.columns.str.strip()
diabetes.rename(columns={'age': 'Año', 'gender': 'Genero', 'bmi': 'IMC', 'blood_pressure': 'Presión Arterial', 'fasting_glucose_level': 'Glucosa en ayunas', 'insulin_level': 'Nivel de insulina', 'HbA1c_level': 'Nivel de insulina Glicosilada', 'cholesterol_level': 'Nivel de colesterol', 'triglycerides_level': 'Nivel de trigliceridos', 'physical_activity_level': 'Nivel de actividad fisica', 'daily_calorie_intake': 'Ingesta diaria de caloria', 'sugar_intake_grams_per_day': 'Ingesta de azucar g/dia', 'sleep_hours': 'Horas de sueño', 'stress_level':'Nivel de estres', 'family_history_diabetes': 'Historial Familiar', 'waist_circumference_cm': 'Circunferencia de cintura cm', 'diabetes_risk_score': 'Puntuacion de riesgo', 'diabetes_risk_category': 'Categoria de riesgo'}, inplace=True)
print(diabetes.columns)
# Out:
# Index(['Patient_ID', 'Año', 'Genero', 'IMC', 'Presión Arterial',
#        'Glucosa en ayunas', 'Nivel de insulina',
#        'Nivel de insulina Glicosilada', 'Nivel de colesterol',
#        'Nivel de trigliceridos', 'Nivel de actividad fisica',
#        'Ingesta diaria de caloria', 'Ingesta de azucar g/dia',
#        'Horas de sueño', 'Nivel de estres', 'Historial Familiar',
#        'Circunferencia de cintura cm', 'Puntuacion de riesgo',
#        'Categoria de riesgo'],
#       dtype='object')

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Patient_ID                     6000 non-null   int64
#  1   Año                            6000 non-null   int64
#  2   Genero                         6000 non-null   object
#  3   IMC                            6000 non-null   float64
#  4   Presión Arterial               6000 non-null   int64
#  5   Glucosa en ayunas              6000 non-null   int64
#  6   Nivel de insulina              6000 non-null   float64
#  7   Nivel de insulina Glicosilada  6000 non-null   float64
#  8   Nivel de colesterol            6000 non-null   int64
#  9   Nivel de trigliceridos         6000 non-null   int64
#  10  Nivel de actividad fisica      6000 non-null   object
#  11  Ingesta diaria de caloria      6000 non-null   int64
#  12  Ingesta de azucar g/dia        6000 non-null   float64
#  13  Horas de sueño                 6000 non-null   float64
#  14  Nivel de estres                6000 non-null   int64
#  15  Historial Familiar             6000 non-null   object
#  16  Circunferencia de cintura cm   6000 non-null   float64
#  17  Puntuacion de riesgo           6000 non-null   float64
#  18  Categoria de riesgo            6000 non-null   object
# dtypes: float64(7), int64(8), object(4)
# memory usage: 890.8+ KB

# %%
diabetes.dropna()
# Out:
#       Patient_ID  Año  Genero   IMC  Presión Arterial  Glucosa en ayunas  \
# 0              1   77  Female  33.8               154                 93
# 1              2   54    Male  19.2               123                 94
# 2              3   25    Male  33.7               141                150
# 3              4   23  Female  32.8               140                145
# 4              5   70    Male  33.7               165                 90
# ...          ...  ...     ...   ...               ...                ...
# 5995        5996   58    Male  21.8               158                 89
# 5996        5997   73    Male  47.3               193                109
# 5997        5998   35    Male  31.0               139                 90
# 5998        5999   58    Male  26.2               136                 88
# 5999        6000   54    Male  39.3               158                201
#
#       Nivel de insulina  Nivel de insulina Glicosilada  Nivel de colesterol  \
# 0                  12.1                            5.2                  242
# 1                   4.6                            5.4                  212
# 2                  10.8                            6.9                  247
# 3                  11.6                            6.8                  195
# 4                  18.3                            5.6                  217
# ...                 ...                            ...                  ...
# 5995                6.3                            5.3                  198
# 5996               33.7                            6.1                  250
# 5997               15.1                            5.3                  190
# 5998                6.3                            5.5                  223
# 5999               10.7                            8.3                  240
#
#       Nivel de trigliceridos Nivel de actividad fisica  \
# 0                        194                       Low
# 1                         76                      High
# 2                        221                       Low
# 3                        193                       Low
# 4                        170                  Moderate
# ...                      ...                       ...
# 5995                     132                      High
# 5996                     209                       Low
# 5997                     164                  Moderate
# 5998                     126                      High
# 5999                     223                       Low
#
#       Ingesta diaria de caloria  Ingesta de azucar g/dia  Horas de sueño  \
# 0                          2169                     78.4             8.1
# 1                          1881                     16.5             6.6
# 2                          2811                    147.9             6.7
# 3                          2826                     98.3             4.4
# 4                          2610                     65.8             9.1
# ...                         ...                      ...             ...
# 5995                       1995                     44.1             7.6
# 5996                       3401                     61.4             5.3
# 5997                       3022                     86.7             6.8
# 5998                       2311                     28.2             8.4
# 5999                       2442                    113.1             5.7
#
#       Nivel de estres Historial Familiar  Circunferencia de cintura cm  \
# 0                   4                 No                         101.1
# 1                   3                 No                          60.0
# 2                  10                Yes                         114.7
# 3                   9                Yes                          96.6
# 4                   5                Yes                         107.4
# ...               ...                ...                           ...
# 5995                7                 No                          82.7
# 5996               10                Yes                         150.0
# 5997                3                Yes                         102.7
# 5998                5                 No                          90.6
# 5999                6                 No                         123.8
#
#       Puntuacion de riesgo Categoria de riesgo
# 0                     52.3         Prediabetes
# 1                      3.7            Low Risk
# 2                     87.3           High Risk
# 3                     76.1           High Risk
# 4                     47.7         Prediabetes
# ...                    ...                 ...
# 5995                   0.0            Low Risk
# 5996                 100.0           High Risk
# 5997                  22.3            Low Risk
# 5998                   3.9            Low Risk
# 5999                 100.0           High Risk
#
# [6000 rows x 19 columns]

# %%
diabetes.describe()
# Out:
#         Patient_ID          Año          IMC  Presión Arterial  \
# count  6000.000000  6000.000000  6000.000000       6000.000000
# mean   3000.500000    52.230667    32.939667        144.482500
# std    1732.195139    18.757508     7.510155         17.867248
# min       1.000000    20.000000    16.000000         91.000000
# 25%    1500.750000    36.000000    26.900000        132.000000
# 50%    3000.500000    53.000000    32.750000        144.000000
# 75%    4500.250000    68.000000    38.500000        157.000000
# max    6000.000000    84.000000    50.000000        200.000000
#
#        Glucosa en ayunas  Nivel de insulina  Nivel de insulina Glicosilada  \
# count        6000.000000        6000.000000                    6000.000000
# mean          106.105500          15.080333                       5.784583
# std            31.213994           9.245581                       0.956614
# min            60.000000           2.000000                       4.100000
# 25%            87.000000           7.100000                       5.200000
# 50%            96.000000          13.800000                       5.500000
# 75%           114.000000          21.000000                       6.100000
# max           281.000000          55.900000                      11.000000
#
#        Nivel de colesterol  Nivel de trigliceridos  Ingesta diaria de caloria  \
# count          6000.000000             6000.000000                6000.000000
# mean            217.490667              177.351500                2479.547000
# std              24.888595               51.897606                 548.410642
# min             139.000000               50.000000                1200.000000
# 25%             200.000000              137.000000                2055.000000
# 50%             217.000000              173.000000                2385.000000
# 75%             234.000000              213.000000                2848.250000
# max             309.000000              383.000000                5249.000000
#
#        Ingesta de azucar g/dia  Horas de sueño  Nivel de estres  \
# count              6000.000000     6000.000000      6000.000000
# mean                 66.555733        6.998700         5.086500
# std                  39.576891        1.331378         2.342989
# min                   0.000000        4.000000         1.000000
# 25%                  35.100000        6.100000         3.000000
# 50%                  58.300000        7.100000         5.000000
# 75%                  89.300000        8.000000         7.000000
# max                 255.000000       10.000000        10.000000
#
#        Circunferencia de cintura cm  Puntuacion de riesgo
# count                   6000.000000           6000.000000
# mean                     105.049600             48.691417
# std                       25.079335             37.242034
# min                       60.000000              0.000000
# 25%                       84.700000             12.900000
# 50%                      104.600000             43.900000
# 75%                      124.200000             88.800000
# max                      150.000000            100.000000

# %%
columns = ['Año', 'Genero', 'IMC', 'Presión Arterial', 'Glucosa en ayunas', 'Nivel de insulina Glicosilada', 'Nivel de insulina', 'Nivel de colesterol', 'Nivel de trigliceridos', 'Ingesta diaria de caloria', 'Ingesta de azucar g/dia', 'Horas de sueño', 'Nivel de estres', 'Circunferencia de cintura cm', 'Historial Familiar', 'Puntuacion de riesgo']
print("---Reporte de valores en cero ---")
for column in columns:
    print(column, "valores en 0: ", (diabetes[column] == 0).sum())
# Out:
# ---Reporte de valores en cero ---
# Año valores en 0:  0
# Genero valores en 0:  0
# IMC valores en 0:  0
# Presión Arterial valores en 0:  0
# Glucosa en ayunas valores en 0:  0
# Nivel de insulina Glicosilada valores en 0:  0
# Nivel de insulina valores en 0:  0
# Nivel de colesterol valores en 0:  0
# Nivel de trigliceridos valores en 0:  0
# Ingesta diaria de caloria valores en 0:  0
# Ingesta de azucar g/dia valores en 0:  4
# Horas de sueño valores en 0:  0
# Nivel de estres valores en 0:  0
# Circunferencia de cintura cm valores en 0:  0
# Historial Familiar valores en 0:  0
# Puntuacion de riesgo valores en 0:  749

# %%
diabetes[column] = diabetes[column].replace(0, np.nan)

# %%
correlacion = diabetes.corr(numeric_only=True)
print(correlacion["Puntuacion de riesgo"].sort_values(ascending=False))
# Out:
# Puntuacion de riesgo             1.000000
# IMC                              0.853006
# Circunferencia de cintura cm     0.852740
# Nivel de trigliceridos           0.734656
# Ingesta diaria de caloria        0.710987
# Glucosa en ayunas                0.645421
# Presión Arterial                 0.632326
# Nivel de insulina Glicosilada    0.630283
# Ingesta de azucar g/dia          0.604490
# Nivel de colesterol              0.573841
# Nivel de insulina                0.513704
# Nivel de estres                  0.473497
# Año                              0.134921
# Patient_ID                       0.000120
# Horas de sueño                  -0.359216
# Name: Puntuacion de riesgo, dtype: float64

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(10, 6))

sns.regplot(data=diabetes, 
            x="IMC", 
            y="Puntuacion de riesgo", 
            scatter_kws={'alpha':0.5}, 
            line_kws={'color':'red'})

plt.title("Relación Médica: IMC vs Puntuación de Riesgo", fontsize=14)
plt.show()

# %%
diabetes.isnull().sum()
# Out:
# Patient_ID                         0
# Año                                0
# Genero                             0
# IMC                                0
# Presión Arterial                   0
# Glucosa en ayunas                  0
# Nivel de insulina                  0
# Nivel de insulina Glicosilada      0
# Nivel de colesterol                0
# Nivel de trigliceridos             0
# Nivel de actividad fisica          0
# Ingesta diaria de caloria          0
# Ingesta de azucar g/dia            0
# Horas de sueño                     0
# Nivel de estres                    0
# Historial Familiar                 0
# Circunferencia de cintura cm       0
# Puntuacion de riesgo             749
# Categoria de riesgo                0
# dtype: int64

# %%
plt.figure(figsize=(12, 8))

sns.heatmap(correlacion, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Mapa de Calor: Factores de Riesgo de Diabetes", fontsize=15)
plt.show()
